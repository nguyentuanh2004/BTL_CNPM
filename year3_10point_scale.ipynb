# %%
import pandas as pd
import numpy as np

# %%
pima=pd.read_excel("data/year3.xlsx")

# %%
pima=pima.drop(columns=['MSSV','Ngày Sinh','diemtbclan1','diemtbccaonhat','Trung bình cộng học tập', 'Trung bình cộng tích lũy','tongsomonconno','tongsohoctrinhconno','Số tín chỉ tích lũy','Điểm rèn luyện'])
pima
# Out:
#     Kỹ năng mềm Triết học Mác- Lê Nin F1 Đại số tuyến tính Giải tích 1  \
# 0             1                        1                 1           1
# 1             2                        3                 3           3
# 2           4.9                      NaN               4.4         5.3
# 3           7.6                      NaN               6.4         8.8
# 4           6.3                      NaN               6.7         6.7
# ..          ...                      ...               ...         ...
# 680        7.50                        9              6.30        5.60
# 681           7                  3.90, 7              5.20        5.50
# 682        8.60                        9              7.80        5.30
# 683        7.70                     8.60              9.60           6
# 684        7.70                     8.60              7.10        8.40
#
#     Tin học đại cương Những nguyên lý cơ bản của chủ nghĩa Mác- Lê Nin F1  \
# 0                   1                                                  1
# 1                   3                                                  2
# 2                 6.8                                                6.9
# 3                 5.2                                                8.6
# 4                 7.5                                                6.5
# ..                ...                                                ...
# 680              8.50                                                NaN
# 681              4.60                                                NaN
# 682              8.60                                                NaN
# 683              8.20                                                NaN
# 684              4.90                                                NaN
#
#     Chủ nghĩa xã hội khoa học Kinh tế chính trị Mác-Lênin Vật lý điện từ  \
# 0                           2                           2              2
# 1                           2                           2              3
# 2                         NaN                         NaN            4.6
# 3                         NaN                         NaN            6.0
# 4                         NaN                         NaN            6.2
# ..                        ...                         ...            ...
# 680                      8.50                        7.30              5
# 681                         8                        6.30        2.60, 7
# 682                      9.20                        8.90           5.90
# 683                      9.20                        7.30              7
# 684                      9.70                        8.10           4.70
#
#     Giải tích 2  ... Môn tự chọn 8 Trí tuệ nhân tạo Môn tự chọn 9  \
# 0             2  ...       6, 6, 6                7          7, 7
# 1             3  ...       3, 3, 3                3          3, 3
# 2           6.0  ...           7.5              7.6           7.5
# 3           8.0  ...           8.1              9.9           7.3
# 4           4.5  ...           6.4              6.9           5.9
# ..          ...  ...           ...              ...           ...
# 680        9.10  ...          7.50             0, 3        0, 1.5
# 681   2.80, 7.7  ...          7.80             5.20          5.40
# 682        7.10  ...           NaN          3.40, 7          6.10
# 683        7.30  ...           NaN             9.40          5.70
# 684        4.20  ...           NaN             9.40             6
#
#     Môn tự chọn 10 Môn tự chọn 11 Môn tự chọn 12    Môn tự chọn 13  \
# 0             7, 7           7, 7           7, 7  7, 7, 7, 7, 7, 7
# 1             3, 3           3, 3           3, 3  3, 3, 3, 3, 3, 3
# 2              7.8            6.9            6.7               7.9
# 3              8.7            8.7            8.5               8.7
# 4              9.4            6.6            7.2               8.5
# ..             ...            ...            ...               ...
# 680           6.50           0, 0           0.80           0.80, 0
# 681              8           4.20           6.20         1.10, 7.6
# 682           6.10           7.80      0.60, 7.4              8.30
# 683           7.40           8.20           6.10              6.50
# 684           6.90           4.70           6.70              7.90
#
#     Thực tập tốt nghiệp  Đồ án tốt nghiệp Xếp loại học tập
# 0                      8                8              NaN
# 1                      2               10              NaN
# 2                    8.6              8.5              Khá
# 3                    9.4              8.3             Giỏi
# 4                    8.6              7.4              Khá
# ..                   ...              ...              ...
# 680                    0              NaN    Chua xep loai
# 681                    9              NaN    Chua xep loai
# 682                 8.40              NaN    Chua xep loai
# 683                    0              NaN    Chua xep loai
# 684                    9              NaN    Chua xep loai
#
# [685 rows x 48 columns]

# %%
pima=pima.drop(columns=['Những nguyên lý cơ bản của chủ nghĩa Mác- Lê Nin F1','Những nguyên lý cơ bản của chủ nghĩa Mác- Lê Nin F2','Chủ nghĩa xã hội khoa học','Kinh tế chính trị Mác-Lênin','Triết học Mác- Lê Nin F1'])
pima
# Out:
#     Kỹ năng mềm Đại số tuyến tính Giải tích 1 Tin học đại cương  \
# 0             1                 1           1                 1
# 1             2                 3           3                 3
# 2           4.9               4.4         5.3               6.8
# 3           7.6               6.4         8.8               5.2
# 4           6.3               6.7         6.7               7.5
# ..          ...               ...         ...               ...
# 680        7.50              6.30        5.60              8.50
# 681           7              5.20        5.50              4.60
# 682        8.60              7.80        5.30              8.60
# 683        7.70              9.60           6              8.20
# 684        7.70              7.10        8.40              4.90
#
#     Vật lý điện từ Giải tích 2 Lập trình nâng cao Môn tự chọn 1 Thiết kế Web  \
# 0                2           2                  2          3, 3            3
# 1                3           3                  3          2, 2            3
# 2              4.6         6.0           2.1, 8.3           5.1          6.6
# 3              6.0         8.0                9.4           5.7          4.2
# 4              6.2         4.5                6.2           5.4          5.3
# ..             ...         ...                ...           ...          ...
# 680              5        9.10               8.10          5.90         5.90
# 681        2.60, 7   2.80, 7.7          2.70, 7.3          7.20      1.20, 5
# 682           5.90        7.10               5.10        3, 6.9         5.80
# 683              7        7.30               9.70          9.30         5.70
# 684           4.70        4.20               4.70          6.20    1.90, 4.8
#
#     Toán rời rạc  ... Môn tự chọn 8 Trí tuệ nhân tạo Môn tự chọn 9  \
# 0              3  ...       6, 6, 6                7          7, 7
# 1              3  ...       3, 3, 3                3          3, 3
# 2            5.8  ...           7.5              7.6           7.5
# 3            6.1  ...           8.1              9.9           7.3
# 4            4.8  ...           6.4              6.9           5.9
# ..           ...  ...           ...              ...           ...
# 680         6.10  ...          7.50             0, 3        0, 1.5
# 681         5.20  ...          7.80             5.20          5.40
# 682            5  ...           NaN          3.40, 7          6.10
# 683         6.70  ...           NaN             9.40          5.70
# 684         6.30  ...           NaN             9.40             6
#
#     Môn tự chọn 10 Môn tự chọn 11 Môn tự chọn 12    Môn tự chọn 13  \
# 0             7, 7           7, 7           7, 7  7, 7, 7, 7, 7, 7
# 1             3, 3           3, 3           3, 3  3, 3, 3, 3, 3, 3
# 2              7.8            6.9            6.7               7.9
# 3              8.7            8.7            8.5               8.7
# 4              9.4            6.6            7.2               8.5
# ..             ...            ...            ...               ...
# 680           6.50           0, 0           0.80           0.80, 0
# 681              8           4.20           6.20         1.10, 7.6
# 682           6.10           7.80      0.60, 7.4              8.30
# 683           7.40           8.20           6.10              6.50
# 684           6.90           4.70           6.70              7.90
#
#     Thực tập tốt nghiệp  Đồ án tốt nghiệp Xếp loại học tập
# 0                      8                8              NaN
# 1                      2               10              NaN
# 2                    8.6              8.5              Khá
# 3                    9.4              8.3             Giỏi
# 4                    8.6              7.4              Khá
# ..                   ...              ...              ...
# 680                    0              NaN    Chua xep loai
# 681                    9              NaN    Chua xep loai
# 682                 8.40              NaN    Chua xep loai
# 683                    0              NaN    Chua xep loai
# 684                    9              NaN    Chua xep loai
#
# [685 rows x 43 columns]

# %%
pima=pima.drop(columns=['Tư tưởng Hồ Chí Minh','Lịch sử Đảng Cộng sản Việt Nam'])
pima
# Out:
#     Kỹ năng mềm Đại số tuyến tính Giải tích 1 Tin học đại cương  \
# 0             1                 1           1                 1
# 1             2                 3           3                 3
# 2           4.9               4.4         5.3               6.8
# 3           7.6               6.4         8.8               5.2
# 4           6.3               6.7         6.7               7.5
# ..          ...               ...         ...               ...
# 680        7.50              6.30        5.60              8.50
# 681           7              5.20        5.50              4.60
# 682        8.60              7.80        5.30              8.60
# 683        7.70              9.60           6              8.20
# 684        7.70              7.10        8.40              4.90
#
#     Vật lý điện từ Giải tích 2 Lập trình nâng cao Môn tự chọn 1 Thiết kế Web  \
# 0                2           2                  2          3, 3            3
# 1                3           3                  3          2, 2            3
# 2              4.6         6.0           2.1, 8.3           5.1          6.6
# 3              6.0         8.0                9.4           5.7          4.2
# 4              6.2         4.5                6.2           5.4          5.3
# ..             ...         ...                ...           ...          ...
# 680              5        9.10               8.10          5.90         5.90
# 681        2.60, 7   2.80, 7.7          2.70, 7.3          7.20      1.20, 5
# 682           5.90        7.10               5.10        3, 6.9         5.80
# 683              7        7.30               9.70          9.30         5.70
# 684           4.70        4.20               4.70          6.20    1.90, 4.8
#
#     Toán rời rạc  ... Môn tự chọn 8 Trí tuệ nhân tạo Môn tự chọn 9  \
# 0              3  ...       6, 6, 6                7          7, 7
# 1              3  ...       3, 3, 3                3          3, 3
# 2            5.8  ...           7.5              7.6           7.5
# 3            6.1  ...           8.1              9.9           7.3
# 4            4.8  ...           6.4              6.9           5.9
# ..           ...  ...           ...              ...           ...
# 680         6.10  ...          7.50             0, 3        0, 1.5
# 681         5.20  ...          7.80             5.20          5.40
# 682            5  ...           NaN          3.40, 7          6.10
# 683         6.70  ...           NaN             9.40          5.70
# 684         6.30  ...           NaN             9.40             6
#
#     Môn tự chọn 10 Môn tự chọn 11 Môn tự chọn 12    Môn tự chọn 13  \
# 0             7, 7           7, 7           7, 7  7, 7, 7, 7, 7, 7
# 1             3, 3           3, 3           3, 3  3, 3, 3, 3, 3, 3
# 2              7.8            6.9            6.7               7.9
# 3              8.7            8.7            8.5               8.7
# 4              9.4            6.6            7.2               8.5
# ..             ...            ...            ...               ...
# 680           6.50           0, 0           0.80           0.80, 0
# 681              8           4.20           6.20         1.10, 7.6
# 682           6.10           7.80      0.60, 7.4              8.30
# 683           7.40           8.20           6.10              6.50
# 684           6.90           4.70           6.70              7.90
#
#     Thực tập tốt nghiệp  Đồ án tốt nghiệp Xếp loại học tập
# 0                      8                8              NaN
# 1                      2               10              NaN
# 2                    8.6              8.5              Khá
# 3                    9.4              8.3             Giỏi
# 4                    8.6              7.4              Khá
# ..                   ...              ...              ...
# 680                    0              NaN    Chua xep loai
# 681                    9              NaN    Chua xep loai
# 682                 8.40              NaN    Chua xep loai
# 683                    0              NaN    Chua xep loai
# 684                    9              NaN    Chua xep loai
#
# [685 rows x 41 columns]

# %%
pima=pima.drop(columns=['Đường lối cách mạng Đảng Cộng sản Việt Nam'])
pima
# Out:
#     Kỹ năng mềm Đại số tuyến tính Giải tích 1 Tin học đại cương  \
# 0             1                 1           1                 1
# 1             2                 3           3                 3
# 2           4.9               4.4         5.3               6.8
# 3           7.6               6.4         8.8               5.2
# 4           6.3               6.7         6.7               7.5
# ..          ...               ...         ...               ...
# 680        7.50              6.30        5.60              8.50
# 681           7              5.20        5.50              4.60
# 682        8.60              7.80        5.30              8.60
# 683        7.70              9.60           6              8.20
# 684        7.70              7.10        8.40              4.90
#
#     Vật lý điện từ Giải tích 2 Lập trình nâng cao Môn tự chọn 1 Thiết kế Web  \
# 0                2           2                  2          3, 3            3
# 1                3           3                  3          2, 2            3
# 2              4.6         6.0           2.1, 8.3           5.1          6.6
# 3              6.0         8.0                9.4           5.7          4.2
# 4              6.2         4.5                6.2           5.4          5.3
# ..             ...         ...                ...           ...          ...
# 680              5        9.10               8.10          5.90         5.90
# 681        2.60, 7   2.80, 7.7          2.70, 7.3          7.20      1.20, 5
# 682           5.90        7.10               5.10        3, 6.9         5.80
# 683              7        7.30               9.70          9.30         5.70
# 684           4.70        4.20               4.70          6.20    1.90, 4.8
#
#     Toán rời rạc  ... Môn tự chọn 8 Trí tuệ nhân tạo Môn tự chọn 9  \
# 0              3  ...       6, 6, 6                7          7, 7
# 1              3  ...       3, 3, 3                3          3, 3
# 2            5.8  ...           7.5              7.6           7.5
# 3            6.1  ...           8.1              9.9           7.3
# 4            4.8  ...           6.4              6.9           5.9
# ..           ...  ...           ...              ...           ...
# 680         6.10  ...          7.50             0, 3        0, 1.5
# 681         5.20  ...          7.80             5.20          5.40
# 682            5  ...           NaN          3.40, 7          6.10
# 683         6.70  ...           NaN             9.40          5.70
# 684         6.30  ...           NaN             9.40             6
#
#     Môn tự chọn 10 Môn tự chọn 11 Môn tự chọn 12    Môn tự chọn 13  \
# 0             7, 7           7, 7           7, 7  7, 7, 7, 7, 7, 7
# 1             3, 3           3, 3           3, 3  3, 3, 3, 3, 3, 3
# 2              7.8            6.9            6.7               7.9
# 3              8.7            8.7            8.5               8.7
# 4              9.4            6.6            7.2               8.5
# ..             ...            ...            ...               ...
# 680           6.50           0, 0           0.80           0.80, 0
# 681              8           4.20           6.20         1.10, 7.6
# 682           6.10           7.80      0.60, 7.4              8.30
# 683           7.40           8.20           6.10              6.50
# 684           6.90           4.70           6.70              7.90
#
#     Thực tập tốt nghiệp  Đồ án tốt nghiệp Xếp loại học tập
# 0                      8                8              NaN
# 1                      2               10              NaN
# 2                    8.6              8.5              Khá
# 3                    9.4              8.3             Giỏi
# 4                    8.6              7.4              Khá
# ..                   ...              ...              ...
# 680                    0              NaN    Chua xep loai
# 681                    9              NaN    Chua xep loai
# 682                 8.40              NaN    Chua xep loai
# 683                    0              NaN    Chua xep loai
# 684                    9              NaN    Chua xep loai
#
# [685 rows x 40 columns]

# %%
for index, row in pima.iterrows():
    # Duyệt qua từng ô trong hàng
    for column in pima.columns:
        # Kiểm tra xem có dấu phẩy giữa hai giá trị không
        if ',' in str(row[column]):
            # Tách giá trị thành hai phần
            values = str(row[column]).split(',')
            # Chuyển đổi các giá trị thành số nguyên
            values = [float(value) if value != '' else np.nan for value in values]
            # Lấy giá trị lớn hơn
            max_value = max(values)
            # Cập nhật lại giá trị trong ô thành giá trị lớn hơn
            pima.at[index, column] = max_value

# %%
pima=pima.drop([0,1])
pima=pima.fillna(0)

# %%
pima.to_excel('data/year3_clean.xlsx',index=False)
df=pima.copy()
X=df.drop('Xếp loại học tập',axis=1)
Y= df['Xếp loại học tập']

# %%
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=1) # 90% training and 10% test
from sklearn import tree
model=tree.DecisionTreeClassifier()
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=model.predict(X_test)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8097560975609757

# %%
#naive bayes
from sklearn.naive_bayes import GaussianNB
# Build a Gaussian Classifier
model_naive = GaussianNB()
model_naive.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred_naive=model_naive.predict(X_test)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred_naive))
# Out:
# Accuracy: 0.926829268292683

# %%
import pickle
pickle.dump(model,open('Pickle/year3_10point_scale.pkl','wb'))
pickle.dump(model_naive,open('Pickle/year3_10point_scale_naive.pkl','wb'))
